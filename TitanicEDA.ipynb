# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
from google.colab import drive
drive.mount('/content/drive/Titanic')

# %cd /content/drive/My Drive/Titanic/
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-47f80ad828a9> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive/Titanic')
#       3
#       4 get_ipython().magic('cd /content/drive/My Drive/Titanic/')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     252             ': timeout during initial read of root folder; for more info: '
#     253             'https://research.google.com/colaboratory/faq.html#drive-timeout')
# --> 254       raise ValueError('mount failed' + extra_reason)
#     255     elif case == 2:
#     256       # Not already authorized, so do the authorization dance.
#
# ValueError: mount failed

# %%
import pandas as pd
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("tested.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-08353fd461f0> in <module>()
#       1 import pandas as pd
# ----> 2 train_df = pd.read_csv("train.csv")
#       3 test_df = pd.read_csv("tested.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
print(train_df.head())

# %%
import seaborn as sb
import matplotlib.pyplot as plt
sb.countplot('Survived', data=train_df)
plt.show()

# %%
train_df.groupby(['Sex','Survived'])['PassengerId'].count()

# %%
train_df[['Sex','Survived']].groupby(['Sex']).mean().plot.bar()
sb.countplot('Sex', hue='Survived',data=train_df)
plt.show()

# %%
sb.countplot('Pclass', hue='Survived', data=train_df)
plt.show()

# %%
pd.crosstab([train_df.Sex,train_df.Survived], train_df.Pclass,margins=True)

# %%
sb.factorplot('Pclass', 'Survived', hue='Sex', data=train_df)

# %%
sb.violinplot('Sex', 'Age', hue='Survived',split=True ,data=train_df)

# %%
sb.violinplot('Pclass', 'Age', hue='Survived',split=True ,data=train_df)

# %%
train_df.columns

# %%
train_df['Initial']=0
for i in train_df:
  train_df['Initial']=train_df.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(train_df.Initial,train_df.Sex)

# %%
train_df['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess',
                               'Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss',
                                'Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
train_df.groupby('Initial')['Age'].mean()

# %%
train_df.loc[(train_df.Age.isnull()) & (train_df.Initial=='Mr'), 'Age']=33
train_df.loc[(train_df.Age.isnull()) & (train_df.Initial=='Miss'), 'Age']=22
train_df.loc[(train_df.Age.isnull()) & (train_df.Initial=='Master'), 'Age']=5
train_df.loc[(train_df.Age.isnull()) & (train_df.Initial=='Mrs'), 'Age']=36
train_df.loc[(train_df.Age.isnull()) & (train_df.Initial=='Other'), 'Age']=46

# %%
train_df.Age.isnull().any()

# %%
train_df[train_df['Survived']==0].Age.plot.hist()

# %%
train_df[train_df['Survived']==1].Age.plot.hist()

# %%
sb.barplot('SibSp','Survived', data=train_df)

# %%
sb.factorplot('SibSp','Survived',data=train_df)

# %%
train_df.isnull().sum()

# %%
corelation=train_df.corr()
sb.heatmap(corelation, annot=True)

# %%
sb.pairplot(train_df)

# %%
sb.relplot(x='Age',y='Survived',hue='Sex',data=train_df)

# %%
sb.distplot(train_df['Age'],bins=20)

# %%
sb.catplot(x='Age', kind='box', data=train_df)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(train_df)
